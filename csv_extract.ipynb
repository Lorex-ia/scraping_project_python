# %%
import pandas as pd

# %%
df = pd.read_csv("inpi.csv", sep=";", encoding='utf-8')

# %%
df.head()
# Out:
#   num_depot origine  annees_publication  annees_delivrance part  \
# 0   1161944  France                2013             2013.0  Non
# 1   0400729  France                2005             2006.0  Non
# 2   0512601  France                2007                NaN  Non
# 3   1150006  France                2012             2014.0  Non
# 4   1101373  France                2012             2014.0  Non
#
#                         type_d_tablissement  num_siren    id_dep     com_code  \
# 0                    Grande Entreprise (GE)  632012100     49478        75108
# 1                         Personne physique        NaN     12620        35238
# 2                         Personne physique        NaN     15837        91477
# 3       Personne physique;Personne physique        NaN  489;7548  69034,69034
# 4  Entreprise de taille Intermédiaire (ETI)  394342299     37732        94021
#
#                              com_nom  ...  \
# 0                          Paris  8e  ...
# ...

# %%
df.tail()
# Out:
#        num_depot origine  annees_publication  annees_delivrance part  \
# 222622   0402041  France                2005                NaN  Non
# 222623   0402056  France                2005             2007.0  Non
# 222624   1058214  France                2012             2013.0  Non
# 222625   1158228  France                2013             2014.0  Non
# 222626   0402205  France                2005             2006.0  Non
#
#                        type_d_tablissement  num_siren id_dep com_code  \
# 222622                   Personne physique        NaN  27732    74183
# 222623  Petite et Moyenne Entreprise (PME)  781229406  50602    16113
# 222624                          Entreprise  365501089  35718    76481
# 222625              Grande Entreprise (GE)  780129987  50585    92012
# 222626                          Entreprise  424672665  41041    92023
#
#                      com_nom  ...                             type  \
# ...

# %%
df_v2 = df.drop(columns=['de_libelle', 'de_sd1_libelle', 'de_sd2_libelle', 'fe_id'], axis=1)

df_v2.head()
# Out:
#   num_depot origine  annees_publication  annees_delivrance part  \
# 0   1161944  France                2013             2013.0  Non
# 1   0400729  France                2005             2006.0  Non
# 2   0512601  France                2007                NaN  Non
# 3   1150006  France                2012             2014.0  Non
# 4   1101373  France                2012             2014.0  Non
#
#                         type_d_tablissement  num_siren    id_dep     com_code  \
# 0                    Grande Entreprise (GE)  632012100     49478        75108
# 1                         Personne physique        NaN     12620        35238
# 2                         Personne physique        NaN     15837        91477
# 3       Personne physique;Personne physique        NaN  489;7548  69034,69034
# 4  Entreprise de taille Intermédiaire (ETI)  394342299     37732        94021
#
#                              com_nom  ...  \
# 0                          Paris  8e  ...
# ...
